# %%
import pandas as pd
import csv

# %%
pd.read_csv('https://raw.githubusercontent.com/hupili/python-for-data-and-media-communication/master/scraper-examples/open_rice/openrice_sample.csv')
# Out:
#                               LAB EAT Restaurant & Bar  \
# 0                                                Shine
# 1                                        Yadllie Plate
# 2                               漁獲浜燒 Toretore Hamayaki
# 3                                       心之食堂 Love Cafe
# 4                                       The Grill Room
# 5                                               Sky726
# 6                                            Burgeroom
# 7                                         樂園 Happyland
# 8                                           The Hwaduk
# 9                                           The Joomak
# 10                            和匠日式燒肉店 Wa Shou Yakiniku
# 11               嵐山日本料理 Arashiyama Japanese Restaurant
# 12                                                Doux
# 13                                 Plato Cafe & Bistro
# 14                                  鳥居居酒屋 tori izakaya
# 15                                      一起果醬 Let's Jam
# ...

# %%
df = pd.read_csv('openrice_sample.csv')

# %%
df
# Out:
#                               LAB EAT Restaurant & Bar  \
# 0                                                Shine
# 1                                        Yadllie Plate
# 2                               漁獲浜燒 Toretore Hamayaki
# 3                                       心之食堂 Love Cafe
# 4                                       The Grill Room
# 5                                               Sky726
# 6                                            Burgeroom
# 7                                         樂園 Happyland
# 8                                           The Hwaduk
# 9                                           The Joomak
# 10                            和匠日式燒肉店 Wa Shou Yakiniku
# 11               嵐山日本料理 Arashiyama Japanese Restaurant
# 12                                                Doux
# 13                                 Plato Cafe & Bistro
# 14                                  鳥居居酒屋 tori izakaya
# 15                                      一起果醬 Let's Jam
# ...

# %%
ls
# Out:
# Week 09 Class Demo.ipynb  openrice_sample.csv

# %%
df = pd.read_csv('openrice_sample.csv',header = None )
df
# Out:
#                                                      0  \
# 0                             LAB EAT Restaurant & Bar
# 1                                                Shine
# 2                                        Yadllie Plate
# 3                               漁獲浜燒 Toretore Hamayaki
# 4                                       心之食堂 Love Cafe
# 5                                       The Grill Room
# 6                                               Sky726
# 7                                            Burgeroom
# 8                                         樂園 Happyland
# 9                                           The Hwaduk
# 10                                          The Joomak
# 11                            和匠日式燒肉店 Wa Shou Yakiniku
# 12               嵐山日本料理 Arashiyama Japanese Restaurant
# 13                                                Doux
# 14                                 Plato Cafe & Bistro
# 15                                  鳥居居酒屋 tori izakaya
# ...

# %%
df.columns =[
    'name','address','price-range','country','style','likes','comments','bookmarks','discounts'
]

# %%
df['price-range'].describe()
# Out:
# count          932
# unique           5
# top       $101-200
# freq           467
# Name: price-range, dtype: object

# %%
df['price-range'].value_counts()
# Out:
# $101-200    467
# $201-400    309
# $51-100     106
# $401-800     46
# $50以下         4
# Name: price-range, dtype: int64

# %%
df['name'].describe()
# Out:
# count           932
# unique          438
# top       La Postre
# freq             10
# Name: name, dtype: object

# %%
df['name'].value_counts()
# Out:
# La Postre                                      10
# 居食屋「和民」 Watami Japanese Casual Restaurant       8
# Plato Cafe & Bistro                             7
# LAB EAT Restaurant & Bar                        7
# FRITES Belgium on Tap                           7
# 相馬日式火鍋 Soma Shabu Shabu                         6
# 養心殿台式養生鍋                                        6
# Mini Friday                                     6
# BRICK LANE                                      6
# 飲茶 Yum Cha                                      6
# 喜來稀肉 Seorae                                     5
# Villa Villa                                     5
# The Grill Room                                  5
# 丼瀛 J-City                                       5
# LA Creperie                                     5
# BOM Cuisine                                     4
# 第三站 Station 3 Cafe                              4
# Lifetastic                                      4
# Amina Modern European                           4
# ...

# %%
df['address'].value_counts()
# Out:
# 灣仔謝斐道154號地下C號舖                               4
# 旺角廣華街48號地下                                   4
# 佐敦德興街7號A-B號舖                                 4
# 旺角洗衣街39號金雞廣場25樓08-09室                        4
# 銅鑼灣駱克道459-461號The L. Square 8樓               4
# 觀塘開源道77號業發大廈一期2樓D室                           4
# 觀塘開源道71號王子大廈5樓B室                             4
# 尖沙咀漆咸道南61-65號首都廣場2樓80-82號舖                   4
# 長沙灣青山道441號地舖                                 4
# 荔枝角長沙灣道883號億利工業中心2樓203室                      4
# 尖沙咀麼地道61號冠華中心地下G1號舖                          4
# 油麻地彌敦道483-485號2樓                             4
# 荃灣大壩街77號地舖                                   4
# 西環石塘咀山道31-37號地下B舖                            4
# 尖沙咀廣東道82-84號流尚坊8樓全層                          4
# 銅鑼灣邊寧頓街13號隆堡柏寧頓酒店地下                          4
# 荔枝角長沙灣道883號億利工業中心1樓12室                       4
# 中環皇后大道中118號2樓                                4
# 赤鱲角香港國際機場航天城東路1號香港天際萬豪酒店大堂                   4
# 尖沙咀棉登徑1號地舖                                   4
# ...

# %%
df['address'] == '佐敦德興街7號A-B號舖'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 902    False
# 903    False
# 904    False
# 905    False
# 906    False
# 907    False
# 908    False
# 909    False
# 910    False
# 911    False
# 912    False
# 913    False
# 914    False
# 915    False
# 916    False
# 917    False
# 918    False
# 919    False
# 920    False
# 921    False
# 922    False
# 923    False
# 924    False
# 925    False
# 926    False
# 927    False
# 928    False
# 929    False
# 930    False
# 931    False
# Name: address, Length: 932, dtype: bool

# %%
df[df['address'] == '佐敦德興街7號A-B號舖']
# Out:
#                      name       address price-range country style  likes  \
# 37   Pom's Kitchen & Deli  佐敦德興街7號A-B號舖    $101-200      西式   西餐廳  268.0
# 292  Pom's Kitchen & Deli  佐敦德興街7號A-B號舖    $101-200      西式   西餐廳  268.0
# 531  Pom's Kitchen & Deli  佐敦德興街7號A-B號舖    $101-200      西式   西餐廳  268.0
# 875  Pom's Kitchen & Deli  佐敦德興街7號A-B號舖    $101-200      西式   西餐廳  268.0
#
#      comments  bookmarks discounts
# 37   (361 食評)      18560    專享特別優惠
# 292  (361 食評)      18560    專享特別優惠
# 531  (361 食評)      18560    專享特別優惠
# 875  (361 食評)      18560    專享特別優惠

# %%
len(df)
# Out:
# 932

# %%
df = df.drop_duplicates()
len(df)
# Out:
# 495

# %%
df['address'].value_counts()
# Out:
# 旺角彌敦道577號高氏大樓4樓                   2
# 觀塘開源道60號駱駝漆大廈3座5樓U室               2
# 太子花園街239號嘉慶苑地下                    2
# 銅鑼灣渣甸街66號Aura on Pennington 2樓    2
# 赤鱲角香港國際機場航天城東路1號香港天際萬豪酒店大堂        2
# 尖沙咀北京道8號香港朗廷酒店低層大堂                2
# 銅鑼灣邊寧頓街13號隆堡柏寧頓酒店地下               2
# 荔枝角長義街10號昌隆工業大廈1樓B-C舖             2
# 尖沙咀彌敦道132號美麗華廣場一期2 樓 207 號舖       2
# 尖沙咀柯士甸道西1號圓方(Elements)2樓2032號舖    2
# 旺角上海街555號香港康得思酒店L樓層               2
# 銅鑼灣怡和街42-44號華人銀行東區大廈2樓            2
# 太子白楊街15-19號萬安大樓地下及1樓              2
# 荃灣大壩街77號地舖                        2
# 荃灣眾安街55號大鴻輝(荃灣)中心17樓              2
# 荔枝角長沙灣道883號億利工業中心1樓12室            2
# 尖沙咀彌敦道132號美麗華廣場一期食四方6樓601號舖       1
# 旺角登打士街56號家樂坊19樓1906室              1
# 觀塘開源道71號王子大廈5樓B室                  1
# 屯門震寰路6號香港屯門貝爾特酒店1樓                1
# 尖沙咀樂道36-50號華源大廈1B-2B閣樓            1
# 將軍澳唐德街9號將軍澳中心1樓163B舖              1
# 大角咀埃華街88-102號大全樓地下B及D號舖           1
# 元朗教育路50號兆明樓地下A號舖                  1
# 荃灣大壩街71號德仁樓第16期地下7號舖              1
# 尖沙咀亞士厘道27號捷利商業大廈8樓                1
# ...

# %%
df[df['address'] == '旺角彌敦道577號高氏大樓4樓']
# Out:
#                name          address price-range country  style  likes  \
# 29   孖啡 Double Cafe  旺角彌敦道577號高氏大樓4樓     $51-100      西式  甜品/糖水  295.0
# 529  孖啡 Double Cafe  旺角彌敦道577號高氏大樓4樓     $51-100      西式  甜品/糖水  295.0
#
#      comments  bookmarks  discounts
# 29   (386 食評)      20621  訂座可享79折優惠
# 529  (386 食評)      20622  訂座可享79折優惠

# %%
len(df)
# Out:
# 495

# %%
df = df.drop_duplicates(subset = 'address')

# %%
len(df)
# Out:
# 479

# %%
df['address'].value_counts()
# Out:
# 銅鑼灣銅鑼灣耀華街3-9號百樂中心19樓           1
# 紅磡黃埔新天地美食坊(第8期)3樓302號舖         1
# 尖沙咀諾士佛臺1號7樓                    1
# 尖沙咀樂道36-50號華源大廈1B-2B閣樓         1
# 旺角登打士街56號家樂坊19樓1906室           1
# 觀塘開源道71號王子大廈5樓B室               1
# 屯門震寰路6號香港屯門貝爾特酒店1樓             1
# 將軍澳唐德街9號將軍澳中心1樓163B舖           1
# 大角咀埃華街88-102號大全樓地下B及D號舖        1
# 尖沙咀彌敦道132號美麗華廣場一期食四方6樓601號舖    1
# 荃灣大壩街71號德仁樓第16期地下7號舖           1
# 尖沙咀亞士厘道27號捷利商業大廈8樓             1
# 元朗教育路50號兆明樓地下A號舖               1
# 大坑新村街42-43號地舖                  1
# 金鐘夏慤道16號遠東金融中心閣樓               1
# 西環加倫臺8-16號地舖                   1
# 太子界限街44號地下                     1
# 尖沙咀柯士甸路2號地舖                    1
# 銅鑼灣耀華街38號Zing! 28-29樓          1
# 中環威靈頓街2-8號威靈頓廣場M88 5樓          1
# 中環善慶街9號地舖                      1
# 尖沙咀北京道65-69號環球商業大廈2樓205-06室    1
# 旺角白布街4號地舖                      1
# 大埔安邦路9號大埔超級城A區地下012A舖          1
# 尖沙咀金巴利道27-33號永利大廈地下20及22號舖     1
# 銅鑼灣登龍街28號永光中心10樓               1
# 銅鑼灣耀華街3號百樂中心12樓1203室           1
# 長沙灣青山道441號地舖                   1
# ...

# %%
df['style'].describe()
df['style'].value_counts()
# Out:
# 火鍋                   57
# 海鮮                   49
# 壽司/刺身                36
# 甜品/糖水                30
# 薄餅                   22
# 酒                    20
# 咖啡店                  16
# 自助餐                  13
# 扒房                   13
# All Day Breakfast    12
# 中菜館                  11
# 串燒                   10
# 烤肉                   10
# 西式                   10
# 酒吧                   10
# 泰國菜                   9
# 法國菜                   9
# 素食                    8
# 多國菜                   8
# 漢堡包                   8
# 西餐廳                   8
# 日式放題                  8
# 韓式炸雞                  6
# Fine Dining           6
# 三文治                   5
# 粉麵/米線                 5
# 沙律                    5
# 咖喱                    5
# 點心                    5
# 酒店餐廳                  4
#                      ..
# 湯品                    3
# 爐端燒                   2
# 同客食飯                  2
# 山珍海味                  2
# 比利時菜                  2
# 包場派對                  2
# 燒烤                    2
# ...

# %%
df[
    df['style'] == '火鍋'
]
# Out:
#                                                   name  \
# 25                              吞POT 雞煲火鍋.住家菜 Lazy Pot
# 56                                            漁火海鮮刺身火鍋
# 59                                 靚煲皇 Supreme Hot Pot
# 64                                     九重鮮 Steam Fresh
# 68                            滾得囍宮廷火鍋小炒 Big Boils Club
# 70                 One More Hotpot 來一鍋 One More Hotpot
# 72                                                蜀府川鍋
# 74                                  火水爐冰室火鍋 Fo Shui Lo
# 75                         八幡屋涮涮鍋 Yahataya Shabu Shabu
# 77    正宗水上人氣鍋專門店 Boat Dweller Steam Hot Pot Specialist
# 79             尚鮮火鍋海鮮料理 Seansin Seafood Hotpot Experts
# 95                                            養心殿台式養生鍋
# 96             尚鮮火鍋海鮮料理 Seansin Seafood Hotpot Experts
# 99                         焱手工涮涮鍋 Yan Handcraft Hotpot
# 105                    稻八日式火鍋炸物放題 Inahachi Shabu Shabu
# 106                                    巧得鍋 How Awesome
# ...

# %%
df[
    (df['style'] == '火鍋')
    &
    (df['bookmarks'] > 2222)
]
# Out:
#                                                   name  \
# 25                              吞POT 雞煲火鍋.住家菜 Lazy Pot
# 56                                            漁火海鮮刺身火鍋
# 59                                 靚煲皇 Supreme Hot Pot
# 64                                     九重鮮 Steam Fresh
# 68                            滾得囍宮廷火鍋小炒 Big Boils Club
# 70                 One More Hotpot 來一鍋 One More Hotpot
# 72                                                蜀府川鍋
# 74                                  火水爐冰室火鍋 Fo Shui Lo
# 75                         八幡屋涮涮鍋 Yahataya Shabu Shabu
# 77    正宗水上人氣鍋專門店 Boat Dweller Steam Hot Pot Specialist
# 79             尚鮮火鍋海鮮料理 Seansin Seafood Hotpot Experts
# 95                                            養心殿台式養生鍋
# 96             尚鮮火鍋海鮮料理 Seansin Seafood Hotpot Experts
# 99                         焱手工涮涮鍋 Yan Handcraft Hotpot
# 105                    稻八日式火鍋炸物放題 Inahachi Shabu Shabu
# 106                                    巧得鍋 How Awesome
# ...

# %%
df.head()
# Out:
#                        name                   address price-range country  \
# 0  LAB EAT Restaurant & Bar  尖沙咀金巴利道87-89號僑豐大厦地下1-2號舖    $201-400      西式
# 1                     Shine        尖沙咀北京道12A號太子集團中心6樓    $201-400      西式
# 2             Yadllie Plate           旺角西洋菜街1號兆萬中心11樓    $101-200     韓國菜
# 3    漁獲浜燒 Toretore Hamayaki      銅鑼灣軒尼詩道525號澳門逸園中心18樓    $201-400     日本菜
# 4            心之食堂 Love Cafe      銅鑼灣耀華街3號百樂中心12樓1203室    $201-400     日本菜
#
#    style  likes  comments  bookmarks           discounts
# 0     海鮮  436.0  (565 食評)      50744         網上訂座可享75折優惠
# 1      酒  693.0  (777 食評)      21136       送 25里數 / 30積分
# 2   韓式炸雞  487.0  (630 食評)      27681  早鳥及消夜時段訂座 可享全單八折優惠
# 3    日本菜  503.0  (524 食評)      19647       送 25里數 / 30積分
# 4  壽司/刺身  490.0  (545 食評)       6580               全單85折

# %%
df.tail()
# Out:
#                    name                  address price-range  country style  \
# 925             Bierhof               太子界限街44號地下     $51-100      德國菜   西餐廳
# 926   紫粵軒 Tze Yuet Heen    將軍澳唐德街3號香港九龍東皇冠假日酒店2樓    $201-400  粵菜 (廣東)    火鍋
# 927  樂雅軒中菜廳 The Balcony         油麻地窩打老道23號城景國際1樓    $201-400  粵菜 (廣東)   中菜館
# 928          Enjoy Chef  荔枝角長沙灣道883號億利工業中心7樓704室    $101-200       西式   多國菜
# 931     小城鎮 Little Town         北角明園西街2-6號明苑中心地舖     $51-100       西式    薄餅
#
#      likes comments  bookmarks                      discounts
# 925   51.0  (63 食評)       1300       餐廳優惠月: 網上訂座以$88享Tapas 套餐
# 926   50.0  (82 食評)       3878          星期一至五訂座及惠顧午市及晚市自選菜譜8折
# 927   42.0  (63 食評)       2496            惠顧午市享85折 當月生日獲贈賀壽蟠桃
# 928   37.0  (61 食評)       3696               訂座可享晚巿廚師推介餐牌七折優惠
# 931   90.0  (93 食評)        660  限時優惠消費滿$600即送香烤德式豬手一客(原價$178)

# %%
df.sort_values(by = 'likes', ascending=False)
# Out:
#                                           name  \
# 1                                        Shine
# 8                                 樂園 Happyland
# 26              神戶屋日韓放題 Kobe Fusion Restaurant
# 5                               The Grill Room
# 3                       漁獲浜燒 Toretore Hamayaki
# 4                               心之食堂 Love Cafe
# 2                                Yadllie Plate
# 11                    和匠日式燒肉店 Wa Shou Yakiniku
# 31                     EAT ME Bar & Restaurant
# 10                                  The Joomak
# 9                                   The Hwaduk
# 33                                  S2 Kitchen
# 7                                    Burgeroom
# 0                     LAB EAT Restaurant & Bar
# 19                                        Ocio
# 17                         街坊Cafe Kaifong Cafe
# 15                          鳥居居酒屋 tori izakaya
# 14                         Plato Cafe & Bistro
# 16                              一起果醬 Let's Jam
# ...

# %%
df.sort_values(by = 'likes', ascending=False)[:5]
# Out:
#                               name                         address  \
# 1                            Shine              尖沙咀北京道12A號太子集團中心6樓
# 8                     樂園 Happyland     尖沙咀北京道65-69號環球商業大廈2樓205-06室
# 26  神戶屋日韓放題 Kobe Fusion Restaurant                  旺角西洋菜街1號兆萬中心8樓
# 5                   The Grill Room  銅鑼灣駱克道459-461號The L. Square 5樓
# 3           漁獲浜燒 Toretore Hamayaki            銅鑼灣軒尼詩道525號澳門逸園中心18樓
#
#    price-range country   style  likes  comments  bookmarks           discounts
# 1     $201-400      西式       酒  693.0  (777 食評)      21136       送 25里數 / 30積分
# 8     $101-200      西式  樓上cafe  574.0  (637 食評)      10097       送 25里數 / 30積分
# 26    $201-400     韓國菜   壽司/刺身  549.0  (675 食評)      16806       送 25里數 / 30積分
# 5     $201-400      西式      扒房  508.0  (662 食評)      32342  網上訂座八折優惠-商務二人或四人套餐
# 3     $201-400     日本菜     日本菜  503.0  (524 食評)      19647       送 25里數 / 30積分

# %%
df.sort_values(by = 'price-range',ascending=False)
# Out:
#                                     name                            address  \
# 931                      小城鎮 Little Town                   北角明園西街2-6號明苑中心地舖
# 435                  御品·千之味 Oi-Shi-Sushi                    深水埗荔枝角道390號C號地舖
# 102                            Rimi Cafe               旺角登打士街43H號登打士廣場20樓全層
# 406                           Café Crêpe                       中環威靈頓街15B號地舖
# 413                         Springfields                         中環擺花街11號地鋪
# 418                   好日咖啡店 GoodDay Cafe                        銅鑼灣希雲街12號地舖
# 428              麥田廚房 Wheatfield Kitchen                    銅鑼灣邊寧頓街13-15號2樓
# 430                 象泰 Jaunty Restaurant  屯門屯門鄉事會路112-140號雅都花園1樓商場118-127號舖
# 85                            Zenon Café                        中環威靈頓街86號地舖
# 443          新記雞粥 Sun Kee Chicken Congee                   筲箕灣筲箕灣道307號地下及1樓
# 714             Oasis Cafe & Party House                旺角亞皆老街83號先施大廈4樓406室
# ...

# %%
df['price-range'].value_counts()
# Out:
# $101-200    231
# $201-400    166
# $51-100      53
# $401-800     26
# $50以下         3
# Name: price-range, dtype: int64

# %%
mapping = {
    '$101-200':200,
    '$201-400':400,
    '$51-100':100,
    '$401-800':800,
    '$50以下':50
}

# %%
mapping
# Out:
# {'$101-200': 200,
#  '$201-400': 400,
#  '$51-100': 100,
#  '$401-800': 800,
#  '$50以下': 50}

# %%
def convert(x):
    return mapping[x]

# %%
convert('$401-800')
# Out:
# 800

# %%
df['price'] = df['price-range'].apply(convert)

# %%
df.sort_values(by='price')
# Out:
#                                        name                      address  \
# 317                              Urban Café         旺角彌敦道566-568A號僑建大廈2樓
# 461         松屋 Matsuya Dessert & Restaurant    西環西營盤第三街142-150號仁信大廈地下F號舖
# 793                            Phytofiz Bar         旺角登打士街56號家樂坊19樓1906室
# 794                                   Bacco                   西貢萬年街21號地下
# 253             7E咖喱王 Khyber Pass Mess Club      尖沙咀彌敦道36-44號重慶大廈E座7樓E2室
# 85                               Zenon Café                  中環威靈頓街86號地舖
# 254                          心選 Choice Cafe            旺角豉油街21號昌記大廈2樓B號舖
# 435                     御品·千之味 Oi-Shi-Sushi              深水埗荔枝角道390號C號地舖
# 265                            Insta Crepes                中環蘇豪伊利近街63號地舖
# 269                           Are U Labeler                  何文田梭椏道25A地舖
# 931                         小城鎮 Little Town             北角明園西街2-6號明苑中心地舖
# 858                            紅蔥頭 Cafe MED        旺角亞皆老街8號朗豪坊11樓25-29號舖
# ...

# %%
df.sort_values(by='price', ascending=False)[:10]
# Out:
#                              name                      address price-range  \
# 431                          FUMI           中環德己立街30-32號加州大廈6樓    $401-800
# 774  碗屋 Wanya Japanese Restaurant  中環皇后大道中139號 The L. Place 1樓    $401-800
# 112          S2 鐵板燒 S2 Teppanyaki             佐敦偉晴街29-37號地下6號舖    $401-800
# 678                       Le Rêve           銅鑼灣耀華街38號Zing! 10樓    $401-800
# 190       尖沙咀凱悅酒店咖啡廳 Cafe (Hyatt)       尖沙咀河內道18號香港尖沙咀凱悅酒店大堂樓層    $401-800
# 706                     MoMo Café             西環干諾道西167號香港萬怡酒店    $401-800
# 231         Amina Modern European          尖沙咀廣東道82-84號流尚坊8樓全層    $401-800
# 444                     Maison ES          灣仔星街1A號地舖 (入口位於電氣街)    $401-800
# 425                     MoMo Café              沙田安平街1號香港沙田萬怡酒店    $401-800
# 424            天外天 Above & Beyond             尖沙咀科學館道17號唯港薈28樓    $401-800
#
#      country        style  likes  comments  bookmarks  \
# 431      日本菜        壽司/刺身   93.0  (103 食評)       5650
# ...
