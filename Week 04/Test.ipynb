# %%
a = 1

# %%
parameter1 = {
    'principal': 10 ** 7,
    'interest': 5 / 100 / 12,
    'period': 20 * 12
}

parameter2 = {
    'principal': 10 ** 7,
    'interest': 5 / 100 / 12,
    'period': 30 * 12
}

parameter3 = {
    'principal': 10 ** 7,
    'interest': 10 / 100 / 12,
    'period': 30 * 12
}

parameters = [parameter1, parameter2, parameter3]

parameters = [
    {
    'principal': 0.5 * 10 ** 7,
    'interest': 5 / 100 / 12,
    'period': 20 * 12
    },
    {
    'principal': 10 ** 7,
    'interest': 5 / 100 / 12,
    'period': 30 * 12
    },
    # {
    # 'principal': 10 ** 7,
    # 'interest': 10 / 100 / 12,
    # 'period': 30 * 12
    # },
    # {
    # 'principal': 10 ** 7,
    # 'interest': 10 / 100 / 12,
    # 'period': 40 * 12
    # },
]



# ==== following are generic === 

for i in range(len(parameters)):
    parameter = parameters[i]

    P = parameter['principal']
    r = parameter['interest']
    n = parameter['period']
    A = P * r * (1 + r) ** n / ((1 + r) ** n - 1)

    print(parameter)
    print('offer=', i, 'A=', A)
    print()
# Out:
# {'principal': 5000000.0, 'interest': 0.004166666666666667, 'period': 240}
# offer= 0 A= 32997.786960832935
#
# {'principal': 10000000, 'interest': 0.004166666666666667, 'period': 360}
# offer= 1 A= 53682.16230121398

# %%
fp = open('result.txt', 'w')

# %%
fp.write('hello')
# Out:
# 5

# %%
fp.close()

# %%
fp = open('result.txt', 'w')
fp.write('hello world')
fp.write(str(A))
fp.close()

# %%
A
# Out:
# 53682.16230121398

# %%
type(A)
# Out:
# float

# %%
type('hello')
# Out:
# str

# %%
str(A)
# Out:
# '53682.16230121398'

# %%
type(str(A))
# Out:
# str

# %%
fp = open('result.txt', 'w')
fp.write('hello world')
fp.write(str(A))
# Out:
# 17

# %%
fp.close()

# %%
'abc' * 10
# Out:
# 'abcabcabcabcabcabcabcabcabcabc'

# %%
fp = open('result.txt', 'w')
fp.write('abc' * 10000)
fp.close()

# %%
fp.write('hello world')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-48485a82f0e4> in <module>()
# ----> 1 fp.write('hello world')
#
# ValueError: I/O operation on closed file.

# %%
fp = open('result.txt', 'w')

fp.write('hello world')
fp.close()

# %%
with open('result.txt', 'w') as fp:
    fp.write('hello world hahahhaha')

# %%
import csv

# %%
csv
# Out:
# <module 'csv' from '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/csv.py'>

# %%
'chapter4-example-name_list.csv'
# Out:
# 'chapter4-example-name_list.csv'

# %%
import csv
with open('chapter4-example-name_list.csv','r') as f: # open CSV
    rows = csv.reader(f) # read CSV
    for row in rows: #loop every row
        print(row)
# Out:
# ['name', 'id', 'gender', 'location', 'phone']
# ['Chico', '1742', 'M', 'KLN', '3344']
# ['Ri', '1743', 'F', 'LOS', '5168']
# ['Ivy', '1655', 'F', 'MK', '7323']

# %%
fp = open('chapter4-example-name_list.csv','r')

# %%
help(csv.reader)
# Out:
# Help on built-in function reader in module _csv:
#
# reader(...)
#     csv_reader = reader(iterable [, dialect='excel']
#                             [optional keyword args])
#         for row in csv_reader:
#             process(row)
#
#     The "iterable" argument can be any object that returns a line
#     of input for each iteration, such as a file object or a list.  The
#     optional "dialect" parameter is discussed below.  The function
#     also accepts optional keyword arguments which override settings
#     provided by the dialect.
#
#     The returned object is an iterator.  Each iteration returns a row
#     of the CSV file (which can span multiple input lines).

# %%
csv_reader = csv.reader(fp)

# %%
csv_reader

# %%
type(csv_reader)
# Out:
# _csv.reader

# %%
help(csv_reader)
# Out:
# Help on reader object:
#
# class reader(builtins.object)
#  |  CSV reader
#  |
#  |  Reader objects are responsible for reading and parsing tabular data
#  |  in CSV format.
#  |
#  |  Methods defined here:
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  dialect
#  |
#  |  line_num

# %%
#iteration

# %%
mylist = list(csv_reader)

# %%
mylist
# Out:
# [['name', 'id', 'gender', 'location', 'phone'],
#  ['Chico', '1742', 'M', 'KLN', '3344'],
#  ['Ri', '1743', 'F', 'LOS', '5168'],
#  ['Ivy', '1655', 'F', 'MK', '7323']]

# %%
type(mylist)
# Out:
# list

# %%
for row in mylist:
    print(row)
# Out:
# ['name', 'id', 'gender', 'location', 'phone']
# ['Chico', '1742', 'M', 'KLN', '3344']
# ['Ri', '1743', 'F', 'LOS', '5168']
# ['Ivy', '1655', 'F', 'MK', '7323']

# %%
mylist
# Out:
# [['name', 'id', 'gender', 'location', 'phone'],
#  ['Chico', '1742', 'M', 'KLN', '3344'],
#  ['Ri', '1743', 'F', 'LOS', '5168'],
#  ['Ivy', '1655', 'F', 'MK', '7323']]

# %%
mylist[1][-1]
# Out:
# '3344'

# %%
[['name', 'id', 'gender', 'location', 'phone'],
 ['Ivy', '1655', 'F', 'MK', '7323']]

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2014-01-01&endtime=2014-01-02'

# %%
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-50-95039fbd75c1> in <module>()
# ----> 1 import requests
#
# ModuleNotFoundError: No module named 'requests'

# %%
# !pip install requests
# Out:
# ...
#     100% |████████████████████████████████| 92kB 7.0MB/s ta 0:00:011
# ...
#     100% |████████████████████████████████| 143kB 12.9MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 143kB 13.9MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 153kB 15.8MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 61kB 21.4MB/s ta 0:00:01
# ...

# %%
import requests

# %%
url
# Out:
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2014-01-01&endtime=2014-01-02'

# %%
r = requests.get(url)

# %%
r.text
# Out:
# '{"type":"FeatureCollection","metadata":{"generated":1538733820000,"url":"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2014-01-01&endtime=2014-01-02","title":"USGS Earthquakes","status":200,"api":"1.5.8","count":319},"features":[{"type":"Feature","properties":{"mag":1.29,"place":"10km SSW of Idyllwild, CA","time":1388620296020,"updated":1457728844428,"tz":-480,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/ci11408890","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci11408890&format=geojson","felt":null,"cdi":null,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":26,"net":"ci","code":"11408890","ids":",ci11408890,","sources":",ci,","types":",cap,focal-mechanism,general-link,geoserve,nearby-cities,origin,phase-data,scitech-link,","nst":39,"dmin":0.06729,"rms":0.09,"gap":51,"magType":"ml","type":"earthquake","title":"M 1.3 - 10km SSW of Idyllwild, CA"},"geometry":{"type":"Point","coordinates":[-116.7776667,33.6633333
# ...

# %%
import json

# %%
json.loads(r.text)
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1538733820000,
#   'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2014-01-01&endtime=2014-01-02',
#   'title': 'USGS Earthquakes',
#   'status': 200,
#   'api': '1.5.8',
#   'count': 319},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 1.29,
#     'place': '10km SSW of Idyllwild, CA',
#     'time': 1388620296020,
#     'updated': 1457728844428,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci11408890',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci11408890&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'ci',
#     'code': '11408890',
#     'ids': ',ci11408890,',
#     'sources': ',ci,',
# ...

# %%
r.json()
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1538733820000,
#   'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2014-01-01&endtime=2014-01-02',
#   'title': 'USGS Earthquakes',
#   'status': 200,
#   'api': '1.5.8',
#   'count': 319},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 1.29,
#     'place': '10km SSW of Idyllwild, CA',
#     'time': 1388620296020,
#     'updated': 1457728844428,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci11408890',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci11408890&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'ci',
#     'code': '11408890',
#     'ids': ',ci11408890,',
#     'sources': ',ci,',
# ...

# %%
data = r.json()

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['type', 'metadata', 'features', 'bbox'])

# %%
data['type']
# Out:
# 'FeatureCollection'

# %%
data['metadata']
# Out:
# {'generated': 1538733820000,
#  'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2014-01-01&endtime=2014-01-02',
#  'title': 'USGS Earthquakes',
#  'status': 200,
#  'api': '1.5.8',
#  'count': 319}

# %%
type(data['features'])
# Out:
# list

# %%
len(data['features'])
# Out:
# 319

# %%
f = data['features'][0]

# %%
type(f)
# Out:
# dict

# %%
f.keys()
# Out:
# dict_keys(['type', 'properties', 'geometry', 'id'])

# %%
f['properties']
# Out:
# {'mag': 1.29,
#  'place': '10km SSW of Idyllwild, CA',
#  'time': 1388620296020,
#  'updated': 1457728844428,
#  'tz': -480,
#  'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci11408890',
#  'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci11408890&format=geojson',
#  'felt': None,
#  'cdi': None,
#  'mmi': None,
#  'alert': None,
#  'status': 'reviewed',
#  'tsunami': 0,
#  'sig': 26,
#  'net': 'ci',
#  'code': '11408890',
#  'ids': ',ci11408890,',
#  'sources': ',ci,',
#  'types': ',cap,focal-mechanism,general-link,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#  'nst': 39,
#  'dmin': 0.06729,
#  'rms': 0.09,
#  'gap': 51,
#  'magType': 'ml',
#  'type': 'earthquake',
#  'title': 'M 1.3 - 10km SSW of Idyllwild, CA'}

# %%
f['geometry']
# Out:
# {'type': 'Point', 'coordinates': [-116.7776667, 33.6633333, 11.008]}

# %%
f['geometry']['coordinates']
# Out:
# [-116.7776667, 33.6633333, 11.008]

# %%
f['properties']['mag']
# Out:
# 1.29

# %%
f['geometry']['coordinates'][0], f['geometry']['coordinates'][1], f['properties']['mag'], f['properties']['time']
# Out:
# (-116.7776667, 33.6633333, 1.29, 1388620296020)

# %%
myevents = []
for f in data['features']:
    myevents.append([
        f['geometry']['coordinates'][0], 
        f['geometry']['coordinates'][1], 
        f['properties']['mag'], 
        f['properties']['time']])

# %%
fp = open('earthquake.csv', 'w')
mywriter = csv.writer(fp)

# %%
mywriter.writerows(myevents)

# %%
fp.close()
