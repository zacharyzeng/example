# %%
url='https://www.indeed.com/q-Data-Journalism-Internship-jobs.html'

# %%
url
# Out:
# 'https://www.indeed.com/q-Data-Journalism-Internship-jobs.html'

# %%
import requests

# %%
r = requests.get(url)

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" dir="ltr">\n<head>\n<meta http-equiv="content-type" content="text/html;charset=UTF-8">\n<script type="text/javascript">\n\n(function ( tk ) { if ( tk && document.images ) { var s="/", q="?", a="&", e="="; (new Image()).src = s+"rpc"+s+"log"+q+"a"+e+"jslat"+a+"tk"+e+tk; } })(\'1cq5qm92jbs5e803\');\n</script>\n<script type="text/javascript" src="/s/0247a00/en_US.js"></script>\n<link href="/s/970d98c/jobsearch_all.css" rel="stylesheet" type="text/css">\n<link rel="alternate" type="application/rss+xml" title="Data Journalism Internship Jobs, Employment" href="http://rss.indeed.com/rss?q=Data+Journalism+Internship">\n<link rel="alternate" media="only screen and (max-width: 640px)" href="/m/jobs?q=Data+Journalism+Internship">\n<link rel="alternate" media="handheld" href="/m/jobs?q=Data+Journalism+Internship">\n<script type="text/javascript">\n    \n    if (typeof window[\'closureReadyCallbacks\'] == \'undefined\') {\n        window[\'closureReadyCallbacks\
# ...

# %%
# !pip install bs4

# %%
import bs4

# %%
from bs4 import BeautifulSoup

# %%
mypage = BeautifulSoup(r.text)
# Out:
# /Users/zengxingjie/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/zengxingjie/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
title = mypage.find('div', attrs = {'class':'turnstileLink'})

# %%
company = mypage.find('span', attrs = {'class':'company'})

# %%
# Out:
# <span class="company">
# <a href="/cmp/Dow-Jones" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=dd0b79100dd35040&amp;jcid=d2621f51dde471d3')" rel="noopener" target="_blank">
#         Dow Jones</a></span>
