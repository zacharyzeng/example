# %%
import datetime
print('Last update:', datetime.datetime.now())
# Out:
# Last update: 2018-10-12 17:33:00.512330

# %%
# %matplotlib inline

import csv
import requests
import json

# %%
r = requests.get('https://api.github.com/repos/hupili/python-for-data-and-media-communication-gitbook/issues?state=closed')

# %%
len(r.text)
# Out:
# 101536

# %%
j = r.json()

# %%
j
# Out:
# [{'url': 'https://api.github.com/repos/hupili/python-for-data-and-media-communication-gitbook/issues/54',
#   'repository_url': 'https://api.github.com/repos/hupili/python-for-data-and-media-communication-gitbook',
#   'labels_url': 'https://api.github.com/repos/hupili/python-for-data-and-media-communication-gitbook/issues/54/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/hupili/python-for-data-and-media-communication-gitbook/issues/54/comments',
#   'events_url': 'https://api.github.com/repos/hupili/python-for-data-and-media-communication-gitbook/issues/54/events',
#   'html_url': 'https://github.com/hupili/python-for-data-and-media-communication-gitbook/pull/54',
#   'id': 368581920,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MjIxNzIzOTY1',
#   'number': 54,
#   'title': 'pull request test',
#   'user': {'login': 'ChicoXYC',
#    'id': 37010763,
#    'node_id': 'MDQ6VXNlcjM3MDEwNzYz',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/37010763?v=4',
# ...
